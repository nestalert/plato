# %%
from counsel import suggestions
from bot import IntentChatbot

if __name__ == "__main__":

    uname = "ice2"
    pwd = "11051989"
    class_suggestions = suggestions(uname, pwd)

    #print("\nWe recommend the following classes:")
    #for i, course in enumerate(class_suggestions, start=1):
       #print(f"{i}. {course}")

    bot = IntentChatbot()
    bot.chat()
# Out:
# Welcome, Amy Pond. You are on semester 5. The period is: Fall.
#
# ...
#
# What can I help you with?
# You:  faculty
# Bot: All contact information can be found on the <<LINK 5>> page. If you type the specific name of the teacher, I can give you their contact information.
# You:  professor
# Bot: All contact information can be found on the <<LINK 5>> page. If you type the specific name of the teacher, I can give you their contact information.
# You:  Smith
# Bot: Here's the contact information for Dr. John Smith:
# Title: Professor of Computer Science
# Email: john.smith@university.edu
# Phone: (555) 123-4567
# Office: Building A, Room 301
# Office Hours: Monday & Wednesday 2-4 PM
# Department: Computer Science
# You:  Dr
# Bot: I'm not sure I understand. Could you rephrase that or type 'help' for options?
# You:  doctor
# Bot: I'm not sure I understand. Could you rephrase that or type 'help' for options?
# You:  Dr smith
# Bot: Here's the contact information for Dr. John Smith:
# ...
