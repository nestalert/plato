# %%
from counsel import suggestions
from bot import IntentChatbot

if __name__ == "__main__":

   uname = "ice1"
   pwd = "abc123"
   if uname is None:
      uname = input("Username: ").strip()
   if pwd is None:
      pwd = input("Password: ").strip()

   result = suggestions(uname, pwd)

   if result is None:
      class_suggestions = None
      welcome_message = None
   else:
      class_suggestions,welcome_message = result
      print(welcome_message)
   bot = IntentChatbot(class_suggestions)
   bot.chat()
# Out:
# Welcome, Rory Williams. You are on semester 1. The period is: Fall.
# Loaded 1 feedback entries.
# Loaded model from chatbot_model.pkl. Intents file hasn't changed.
#
# ==================================================
#
# What can I help you with?
# (Type 'feedback' after any response to correct the bot)
#
# Bot: I can help you with finding your schedule, class, contact information, or suggest classes for you to take.
# (Detected intent: help | Type 'feedback' to correct)
#
# Bot: There's always something happening in the university! Check the events page for more: {LINK 6}
# (Detected intent: event | Type 'feedback' to correct)
#
# Bot: I'm not sure I understand. Could you rephrase that or type 'help' for options?
#
# Bot: If you want to reset the chatbot, please exit the page or reload.
# (Detected intent: exit | Type 'feedback' to correct)
#
# Bot: I'm not sure I understand. Could you rephrase that or type 'help' for options?
#
#
# What should the correct intent be?
# Available intents:
#   1. greeting: Hi
#   2. help: Help
#   3. schedule: What's the schedule?
#   4. class_selection: What classes should I take?
#   5. teacher: Contact
#   6. admin: Admin
#   7. event: What's happening?
#   8. postgrad: Postgrad
#   9. exit: Exit
# Feedback saved successfully.
# Feedback recorded: 'Looking for information' -> teacher
# Bot: Thank you! I'll remember that.
#
# Bot: Goodbye!
