# %%
from counsel import suggestions
from bot import IntentChatbot

if __name__ == "__main__":

   uname = "ice1"
   pwd = "abc123"
   if uname is None:
      uname = input("Username: ").strip()
   if pwd is None:
      pwd = input("Password: ").strip()

   result = suggestions(uname, pwd)

   if result is None:
      class_suggestions = None
      welcome_message = None
   else:
      class_suggestions,welcome_message = result
      print(welcome_message)
   bot = IntentChatbot(class_suggestions)
   bot.chat()
# Out:
# Welcome, Rory Williams. You are on semester 1. The period is: Fall.
# Loaded model from chatbot_model.pkl. Intents file hasn't changed.
#
# ==================================================
#
# What can I help you with?
#
# Bot: All contact information can be found on the faculty page: {LINK 5}. If you type the specific name of the teacher, I can give you their contact information.
#
# Bot: Here's the contact information for Dr. John Smith:
# Title: Professor of Computer Science
# Email: john.smith@university.edu
# Phone: (555) 123-4567
# Office: Building A, Room 301
# Office Hours: Monday & Wednesday 2-4 PM
# Department: Computer Science
#
# Bot: Goodbye!
