# %%
from counsel import suggestions
from bot import IntentChatbot
from assignments import check_assignments
if __name__ == "__main__":

   uname = "ice1"
   pwd = "abc123"
   if uname is None:
      uname = input("Username: ").strip()
      
   if pwd is None:
      pwd = input("Password: ").strip()

   result = suggestions(uname, pwd)

   if result is None:
      class_suggestions = None
      welcome_message = None
   else:
      class_suggestions,welcome_message = result
      print(welcome_message)
      assignments = check_assignments(uname,pwd)
   bot = IntentChatbot(uname,pwd,class_suggestions,assignments)
   bot.chat()
# Out:
# Welcome, Rory Williams. You are on semester 1. The period is: Fall.
#
# Preparing your upcoming assignments list...
#
# Loaded model from chatbot_model.pkl. Intents file hasn't changed.
#
# ==================================================
#
# What can I help you with?
# (Type 'feedback' after any response to correct the bot)
#
# Bot: ID:1. In 293 days. Have tea with the doctor. I need to do this for my PHD. 2026-10-30 17:00:00
# If you wish to add an appointment, type 'create appointment'.
# (Detected intent: appointment | Type 'feedback' to correct)
#
# Bot: Here are your current appointments:
# ID:1. In 293 days. Have tea with the doctor. I need to do this for my PHD. 2026-10-30 17:00:00
#
# Please enter the ID of the appointment you wish to delete.
# (Detected intent: fallback | Type 'feedback' to correct)
#
# Bot: Appointment not found or you don't have permission to delete it.
# (Detected intent: appointment_flow | Type 'feedback' to correct)
#
# Bot: Here are your current appointments:
# ID:1. In 293 days. Have tea with the doctor. I need to do this for my PHD. 2026-10-30 17:00:00
#
# Please enter the ID of the appointment you wish to delete.
# (Detected intent: fallback | Type 'feedback' to correct)
#
# Bot: Goodbye!
